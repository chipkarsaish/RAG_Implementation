# %% [markdown]
# <a href="https://colab.research.google.com/github/chipkarsaish/RAG_Implementation/blob/main/RAG_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrieval Augmented Generation (RAG) with Langchain

# %% [markdown]
# The most common approach in RAG is to create dense vector representations of the knowledge base in order to retrieve text chunks that are semantically similar to a given user query. -> (That ability to find text based on meaning rather than exact keywords is what the sentence is describing)

# %%
! echo "::group::Install Dependencies"
# %pip install uv
! uv pip install "git+https://github.com/ibm-granite-community/utils.git" \
    transformers \
    langchain_classic \
    langchain_community \
    langchain_text_splitters \
    langchain_huggingface sentence_transformers \
    langchain_chroma chromadb \
    "langchain_replicate @ git+https://github.com/ibm-granite-community/langchain-replicate.git" \
    wget
! echo "::endgroup::"
# Out:
# ::group::Install Dependencies
# Collecting uv
#   Downloading uv-0.11.23-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.11.23-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.4/25.4 MB 56.8 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.11.23
# Using Python 3.12.13 environment at: /usr
# Resolved 137 packages in 5.63s
# Prepared 22 packages in 2.95s
# Uninstalled 1 package in 1ms
# Installed 22 packages in 75ms
#  + bcrypt==5.0.0
#  + build==1.5.0
#  + chromadb==1.5.9
#  + durationpy==0.10
#  + ibm-granite-community-utils==0.1.dev180 (from git+https://github.com/ibm-granite-community/utils.git@f2feee44f71c6f210a26f854503ac093bbc61d38)
#  + json-repair==0.61.0
#  + kubernetes==36.0.2
#  + langchain-chroma==1.1.0
#  + langchain-classic==1.0.8
#  + langchain-community==0.4.2
#  + langchain-huggingface==1.2.2
#  + langchain-replicate==1.0.0 (from git+https://github.com/ibm-granite-community/langchain-replicate.git@460fd918116617bdf469787960959db430633e6b)
#  + langchain-text-splitters==1.1.2
#  + onnxruntime==1.27.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + overrides==7.7.0
#  + pybase64==1.4.3
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
#  + replicate==1.0.7
#  - requests==2.32.4
#  + requests==2.34.2
#  + wget==3.2
# ::endgroup::

# %%
## Get Embedding
from langchain_huggingface import HuggingFaceEmbeddings
from transformers import AutoTokenizer

embeddings_model_path = "ibm-granite/granite-embedding-small-english-r2"
embeddings_model = HuggingFaceEmbeddings(
    model_name=embeddings_model_path,
)
embeddings_tokenizer = AutoTokenizer.from_pretrained(embeddings_model_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/12.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/55.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/95.3M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/74 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/20.8k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.58M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
## DAtabase for strong embedding
from langchain_chroma import Chroma

vector_db = Chroma(embedding_function=embeddings_model)

# %%
## Integrate LLM
! pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in /usr/local/lib/python3.12/dist-packages (1.3.9)
# Collecting langchain[google-genai]
#   Downloading langchain-1.3.11-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (1.4.7)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (1.2.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (2.12.3)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Downloading langchain_google_genai-4.2.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (0.8.15)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (3.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai->langchain[google-genai]) (1.68.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.34.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.6.3)
# Downloading langchain-1.3.11-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 4.2 MB/s eta 0:00:00
# Downloading langchain_google_genai-4.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: filetype, langchain-google-genai, langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.9
#     Uninstalling langchain-1.3.9:
#       Successfully uninstalled langchain-1.3.9
# Successfully installed filetype-1.2.0 langchain-1.3.11 langchain-google-genai-4.2.5

# %%
from google.colab import userdata
from langchain.chat_models import init_chat_model
import os

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
## Import Document
import os
import wget

filename = 'text.txt'
url = 'https://raw.githubusercontent.com/puffer20/RAG_sample_text/refs/heads/main/text.txt'

if not os.path.isfile(filename):
  wget.download(url, out=filename)

# %%
## Chunk the text
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter

loader = TextLoader(filename)
documents = loader.load()
text_splitter = CharacterTextSplitter.from_huggingface_tokenizer(
    tokenizer=embeddings_tokenizer,
    chunk_size=100,
    chunk_overlap=0,
)
texts = text_splitter.split_documents(documents)
doc_id = 0
for text in texts:
    text.metadata["doc_id"] = (doc_id:=doc_id+1)
print(f"{len(texts)} text document chunks created")
# Out:
# /tmp/ipykernel_1122/3799872046.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# WARNING:langchain_text_splitters.base:Created a chunk of size 2271, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 1130, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 675, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 730, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 509, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 157, which is longer than the specified 100
# 7 text document chunks created

# %%
## Populate the vector database
ids = vector_db.add_documents(texts)
print(f"{len(ids)} documents added to the vector database")
# Out:
# 7 documents added to the vector database

# %%
## quering
query = "When did germany surrendered unconditionally?"
docs = vector_db.similarity_search(query)
print(f"{len(docs)} documents returned")
for doc in docs:
    print(doc)
    print("=" * 80)  # Separator for clarity
# Out:
# 4 documents returned
# page_content='The Battle of the Bulge caught the Allies off guard. The German armor pushed a sixty-mile deep indentation into the American lines. At the vital road junction of Bastogne, the US 101st Airborne Division was completely surrounded, outgunned, and short on winter gear. When the German commander demanded their surrender, the American commander, Brigadier General Anthony McAuliffe, delivered a legendary one-word reply: "Nuts!"The Americans held Bastogne. By late December, the skies cleared, allowing Allied fighter-bombers to strike German fuel columns. Patton executed a brilliant tactical shift, turning his entire army ninety degrees north in the snow to relieve the city. The German offensive exhausted its last strategic oil reserves, leaving the Wehrmacht defenseless against the final Allied advance into Germany.Act V: The Agony and the End (1945)The final year of the war was an exercise in total destruction. Germany was subjected to a relentless round-the-clock bombing campaign: the US Army Air Forces struck industrial targets by day, while the British RAF bombed cities by night. In February 1945, the firebombing of Dresden turned a historic cultural center into a hurricane of flame, killing tens of thousands of civilians and demonstrating the horrific reality of total war.In January, the Red Army launched its Vistula-Oder Offensive, surging out of Poland and into Germany proper. Millions of German civilians fled westward into the freezing winter to escape the advancing Soviet soldiers, who carried deep resentment from years of Nazi brutality on Russian soil.By April, Soviet forces under Marshals Zhukov and Ivan Konev had surrounded Berlin. The Battle of Berlin was fought with desperate savagery through the streets of the ruined capital. The remaining defenders consisted largely of elderly men from the Volkssturm (Home Guard) and children from the Hitler Youth, armed with anti-tank rockets against Soviet armor.                 THE REDOX OF TOTAL COLLAPSE (April-May 1945)
#
#                  Soviets Encircle Berlin      US/Soviet Troops Meet
#                     [April 25, 1945]            [Elbe River Linkup]
#                            │                             │
#                            ▼                             ▼
#                  Hitler's Führerbunker          Germany Surrenders Unconditionally
#                   Suicide (April 30)                V-E Day (May 8, 1945)
# Thirty feet beneath the Reich Chancellery, in a concrete bunker, Adolf Hitler spent his final days map-reading ghost armies that no longer existed. On April 30, 1945, as Soviet troops fought within blocks of his bunker, Hitler shot himself. His body was carried up to the chancellery garden and burned with gasoline, according to his instructions.On May 2, the Soviet flag was raised over the Reichstag building. On May 8, 1945—Victory in Europe (V-E) Day—German representatives signed an unconditional surrender at Allied headquarters in Reims, France. The European war was over, revealing the full horror of the concentration camps to a shocked international community.                     EUROPEAN TERMINATION LANDMARKS
#
#      April 25, 1945: Allied Linkup at Elbe River (Germany split)
#      April 30, 1945: Hitler commits suicide in Führerbunker
#      May 2, 1945:    Berlin garrison surrenders to Soviet forces
#      May 8, 1945:    V-E Day marked across Allied nations
# Yet, across the globe, the Pacific war continued to burn.The US island-hopping campaign had brought American forces to the inner defensive ring of the Japanese Empire. In early 1945, US Marines landed on the volcanic ash of Iwo Jima and the islands of Okinawa.
# The fighting on these islands reached a pitch of fanaticism never seen before. Japan turned to the Kamikaze (Divine Wind)—suicide pilots who crashed explosive-laden aircraft into American warships. On Okinawa, over 100,000 Japanese soldiers and at least as many Okinawan civilians died in a ninety-day battle. The Japanese military command prepared Operation Ketsu-Go—a plan for the total mobilization of the civilian population, armed with bamboo spears, to defend the home islands to the last person.Faced with projections of up to a million Allied casualties for a land invasion of Japan, the newly sworn-in US President Harry S. Truman—
#
# But Hitler’s eyes were fixed firmly on the East. He viewed the British holdout as a minor nuisance; his ultimate ideological goal had always been the destruction of Soviet Communism and the enslavement of the Slavic peoples.On June 22, 1941, Hitler launched Operation Barbarossa. It remains the largest military invasion in human history. Over three million German and Axis soldiers, supported by thousands of tanks and aircraft, surged across a 1,800-mile front into the Soviet Union.Stalin was caught completely unprepared. He had ignored dozens of explicit intelligence warnings from his own spies and from British intelligence, believing Hitler would not risk a two-front war. In the opening weeks, Barbarossa achieved staggering success. The German Panzers executed massive double-envelopments, trapping and capturing entire Soviet armies at Minsk, Smolensk, and Kiev. Hundreds of thousands of Soviet soldiers marched into a brutal captivity where the majority would perish from starvation and exposure.Behind the advancing Wehrmacht units came the Einführung—the Einsatzgruppen. These were specialized SS mobile killing squads. Their mission was the systematic liquidation of Jews, communists, intellectuals, and anyone deemed an enemy of the Reich. They marked the transition of Nazi racial policy from discrimination to mass industrial murder, a dark path that would soon lead to the construction of specialized extermination centers like Auschwitz-Birkenau, Treblinka, and Sobibor. This systematic genocide, the Holocaust, would ultimately claim the lives of six million European Jews and millions of others.As the summer turned to autumn, the vastness of the Russian landscape began to take its toll on the invaders. The German army was highly mechanized at its tip, but relied on millions of horses for its supply lines. The Russian roads, unpaved and primitive, turned into oceans of thick, unnavigable mud during the autumn rains—a seasonal phenomenon known as the rasputitsa. Advancements slowed to a crawl.By November, the mud froze solid. The German high command welcomed the frost, believing it would allow their Panzers to make a final dash to capture Moscow. They could see the glittering spires of the Kremlin through their field glasses. But the German soldiers were still wearing their summer uniforms; their weapons’ grease froze solid, and their engines had to be kept alive by lighting small fires beneath them.Then came the true Russian winter, with temperatures dropping to minus forty degrees. On December 5, 1941, the German offensive finally ground to a halt in the deep snowdrifts outside Moscow. The next morning, Soviet General Georgy Zhukov unleashed a massive counteroffensive. He used fresh, well-equipped Siberian divisions trained for sub-zero combat, who had been transferred west after Soviet intelligence confirmed that Japan would not attack Russia from the east. The Wehrmacht was thrown back from the gates of Moscow, its myth of invincibility broken forever.OPERATIONAL TIMELINE: THE EASTERN FRONTIER' metadata={'doc_id': 2, 'source': 'text.txt'}
# ================================================================================

# %% [markdown]
# ### Automate pipeline
#  User Query
#     ->
# Retriever
#     ->
# Relevant Documents
#     ->
# Prompt Construction
#     ->
# LLM
#     ->
# Answer

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter

# Step 1: Define the prompt template
prompt_template = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context:

<context>
{context}
</context>

Question: {input}
""")

# Step 2: Define a runnable to format documents into a single string
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Step 3: Build the RAG chain explicitly using LCEL
# This chain will:
# 1. Retrieve documents based on the input query.
# 2. Format these documents into a single string.
# 3. Combine the formatted context string and the input query into the prompt.
# 4. Pass the final prompt message to the LLM.

rag_chain = (
    {
        "context": itemgetter("input") | vector_db.as_retriever() | format_docs, # Retrieve, then format
        "input": itemgetter("input"), # Keep the original input
    }
    | prompt_template # Apply the prompt template to get a ChatPromptValue
    | model # Invoke the LLM with the ChatPromptValue
)

# %%
from ibm_granite_community.notebook_utils import wrap_text

output = rag_chain.invoke({"input": query})

print(wrap_text(output.content)) # LLM output is a BaseMessage, access content
# Out:
# Germany surrendered unconditionally on May 8, 1945.
